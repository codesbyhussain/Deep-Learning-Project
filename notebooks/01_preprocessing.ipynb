# %% [markdown]
# # 01 — Preprocessing
#
# Preprocessing and split creation. Uses `src.data` and `src.utils`.

# %%
from src.data import load_raw_dataset, create_splits, save_splits
from src.utils import load_config, get_splits_dir
